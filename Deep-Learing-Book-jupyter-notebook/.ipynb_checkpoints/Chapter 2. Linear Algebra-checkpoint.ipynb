# %% [markdown]
# # Machine Learning
#
# # 2 Linear Algebra

# %% [markdown]
# p31-1:
# + ~~~~~~~~~~~~~~~

# %% [markdown]
# p31-2:
# + ~~

# %% [markdown]
# ## 2.1 Scalars, Vectors, Matrices and Tensors
